# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.image as mpig
from keras.preprocessing.image import ImageDataGenerator
import os

# %% [markdown]
# ##link dataset https://www.kaggle.com/datasets/aryashah2k/breast-ultrasound-images-dataset

# %%
path= '/content/drive/MyDrive/Dataset_BUSI_with_GT'

# %%
kategori = os.listdir(path)
kategori
# Out:
# ['normal', 'benign', 'malignant']

# %%
from tensorflow.image import random_brightness
from tensorflow.keras.utils import load_img

# %%
path_gambar ='/content/drive/MyDrive/Dataset_BUSI_with_GT/normal/normal (1).png'

# %%
image = load_img(path_gambar)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=568x470>

# %%
bright = random_brightness(image, max_delta=1.5);

# %%
plt.imshow(image)
plt.title('gambar sebelum augmentasi')
# Out:
# Text(0.5, 1.0, 'gambar sebelum augmentasi')

# %%
plt.imshow(bright.numpy().astype('uint8'))
plt.title('gambar setelah augmentasi')
# Out:
# Text(0.5, 1.0, 'gambar setelah augmentasi')

# %% [markdown]
# ##imagedatagenerator

# %%
train_datagen = ImageDataGenerator(
    rescale = 1/255.0,

    shear_range = 0.1,
    width_shift_range = 0.3,
    height_shift_range = 0.1,
    zoom_range = 0.1,
    horizontal_flip = True,
    vertical_flip = True,

    validation_split = 0.2
)

val_datagen = ImageDataGenerator(
    rescale = 1/255.0,
    validation_split = 0.2
)

# %%
train_dataset = train_datagen.flow_from_directory(
    path,
    target_size = (150, 150),
    batch_size = 32,
    class_mode = 'categorical',
    subset = 'training'
)

validation_dataset = val_datagen.flow_from_directory(
    path,
    target_size = (150, 150),
    batch_size = 32,
    class_mode = 'categorical',
    subset = 'validation'
)
# Out:
# Found 1263 images belonging to 3 classes.
# Found 315 images belonging to 3 classes.

# %%
train_dataset.class_indices
# Out:
# {'benign': 0, 'malignant': 1, 'normal': 2}

# %%
model = Sequential([
    Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2),

    Conv2D(64, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(2),

    Conv2D(32, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(2),

    Conv2D(32, (3, 3), padding='same', activation='relu'),
    MaxPooling2D(2),

    Flatten(),

    Dense(64, activation='relu'),
    Dense(128, activation='relu'),
    Dense(6, activation='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-26c0bdfe3baa> in <cell line: 1>()
# ----> 1 model = Sequential([
#       2     Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(150, 150, 3)),
#       3     MaxPooling2D(2),
#       4
#       5     Conv2D(64, (3, 3), padding='same', activation='relu'),
#
# NameError: name 'Sequential' is not defined

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-228481410b08> in <cell line: 1>()
# ----> 1 model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#
# NameError: name 'model' is not defined

# %%
model.summary()

# %%
model.fit(train_dataset, validation_data=validation_dataset, epochs=10, verbose=1, steps_per_epochs=10)
