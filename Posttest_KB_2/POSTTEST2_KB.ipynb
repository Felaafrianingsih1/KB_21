# %%
import pandas as pd

# Baca dataset dari file CSV
df = pd.read_csv('HIV_AIDS.csv')
df.head(20)
# Out:
#     Year Borough  UHF       Gender      Age                    Race  \
# 0   2011     All  All          All      All                     All
# 1   2011     All  All         Male      All                     All
# 2   2011     All  All       Female      All                     All
# 3   2011     All  All  Transgender      All                     All
# 4   2011     All  All       Female  13 - 19                     All
# 5   2011     All  All       Female  20 - 29                     All
# 6   2011     All  All       Female  30 - 39                     All
# 7   2011     All  All       Female  40 - 49                     All
# 8   2011     All  All       Female  50 - 59                     All
# 9   2011     All  All       Female      60+                     All
# 10  2011     All  All       Female      All  Asian/Pacific Islander
# 11  2011     All  All       Female      All                   Black
# 12  2011     All  All       Female      All         Latino/Hispanic
# ...

# %%
#menghitung  mean 
df['Yearmean'] = df['Year'].mean()
df.head()
# Out:
#    Year Borough  UHF       Gender      Age Race  HIV diagnoses  \
# 0  2011     All  All          All      All  All           3379
# 1  2011     All  All         Male      All  All           2595
# 2  2011     All  All       Female      All  All            733
# 3  2011     All  All  Transgender      All  All             51
# 4  2011     All  All       Female  13 - 19  All             47
#
#    HIV diagnosis rate  Concurrent diagnoses  % linked to care within 3 months  \
# 0                48.3                   640                                66
# 1                79.1                   480                                66
# 2                21.1                   153                                66
# 3             99999.0                     7                                63
# 4                13.6                     4                                64
#
#    AIDS diagnoses  AIDS diagnosis rate  PLWDHI prevalence  \
# ...

# %%
 HIV diagnoses
import pandas as pd

# Baca dataset dari file CSV
df = pd.read_csv('HIV_AIDS.csv')
# Pilih kolom yang ingin Anda hitung rata-ratanya (ganti 'nama_kolom' dengan nama yang sesuai)
kolom_terpilih = df['HIV diagnoses']

# Hitung rata-ratanya
rata_rata = kolom_terpilih.mean()

# Tampilkan rata-rata
print("Rata-rata dari kolom 'nama_kolom':", rata_rata)
# Out:
# Rata-rata dari kolom 'nama_kolom': 26.49458784346378

# %%
#soal no 1
# Menghitung rata-rata
rata_rata = df['HIV diagnoses'].mean()

# Menghitung standar deviasi
standar_deviasi = df['HIV diagnoses'].std()

# Menghitung nilai minimum
nilai_minimum = df['HIV diagnoses'].min()

# Menghitung nilai maksimum
nilai_maksimum = df['HIV diagnoses'].max()

print("Rata-rata:")
print(rata_rata)

print("\nStandar Deviasi:")
print(standar_deviasi)

print("\nNilai Minimum:")
print(nilai_minimum)

print("\nNilai Maksimum:")
print(nilai_maksimum)
# Out:
# Rata-rata:
# 26.49458784346378
#
# Standar Deviasi:
# 130.99514759418383
#
# Nilai Minimum:
# 0
#
# Nilai Maksimum:
# 3379

# %%
#soal no 2
# Filter kolom-kolom yang hanya bertipe angka
kolom_angka = df.select_dtypes(include=['int', 'float'])

# Menampilkan 10 record pertama dari dataset
kolom_angka= df[['Year', 'HIV diagnoses','HIV diagnosis rate','Concurrent diagnoses','% linked to care within 3 months','AIDS diagnoses','AIDS diagnosis rate','PLWDHI prevalence','% viral suppression','Deaths','Death rate','HIV-related death rate','Non-HIV-related death rate']]


# Menampilkan 10 record pertama dari dataset yang telah difilter
sepuluh_record_pertama = kolom_angka

# Menampilkan hasil
print(sepuluh_record_pertama)
df.head(10)
# Out:
#       Year  HIV diagnoses  HIV diagnosis rate  Concurrent diagnoses  \
# 0     2011           3379                48.3                   640
# 1     2011           2595                79.1                   480
# 2     2011            733                21.1                   153
# 3     2011             51             99999.0                     7
# 4     2011             47                13.6                     4
# ...    ...            ...                 ...                   ...
# 6000  2015              0                 0.0                     0
# 6001  2015              1                72.4                     0
# 6002  2015              2                43.9                     0
# 6003  2015              1               218.9                     0
# 6004  2015              0                 0.0                     0
#
#       % linked to care within 3 months  AIDS diagnoses  AIDS diagnosis rate  \
# ...

# %%
#soal no 3
# Informasi jumlah rekaman
jumlah_rekaman = len(df)

# Informasi jumlah atribut
jumlah_atribut = len(df.columns)

# Nama atribut
nama_atribut = df.columns.tolist()

# Informasi jumlah atribut dengan tipe angka
jumlah_atribut_angka = len(df.select_dtypes(include=['int', 'float']).columns)

# Menyusun informasi dalam dictionary
informasi_dataset = {
    'Jumlah Rekaman': jumlah_rekaman,
    'Jumlah Atribut': jumlah_atribut,
    'Nama Atribut': nama_atribut,
    'Jumlah Atribut dengan Tipe Angka': jumlah_atribut_angka
}

# Menampilkan isi dari dictionary
for kunci, nilai in informasi_dataset.items():
    print(f"{kunci}: {nilai}")
# Out:
# Jumlah Rekaman: 6005
# Jumlah Atribut: 18
# Nama Atribut: ['Year', 'Borough', 'UHF', 'Gender', 'Age', 'Race', 'HIV diagnoses', 'HIV diagnosis rate', 'Concurrent diagnoses', '% linked to care within 3 months', 'AIDS diagnoses', 'AIDS diagnosis rate', 'PLWDHI prevalence', '% viral suppression', 'Deaths', 'Death rate', 'HIV-related death rate', 'Non-HIV-related death rate']
# Jumlah Atribut dengan Tipe Angka: 13

# %%
# Misalkan Anda ingin menampilkan baris ke-5 dari dataset (indeks dimulai dari 0)
baris_tertentu = df.iloc[8]  # Ganti 4 dengan indeks baris yang Anda inginkan

# Tampilkan nilai dari baris yang telah dipilih
print(baris_tertentu)
# Out:
# Artist ID                 10
# Name           Irene Aronson
# Nationality         American
# Gender                Female
# Birth Year            1918.0
# Death Year               NaN
# Name: 8, dtype: object

# %%
df.iloc[5:9,2:4]
# Out:
#    UHF  Gender
# 5  All  Female
# 6  All  Female
# 7  All  Female
# 8  All  Female

# %%
# no 4
import pandas as pd

# Baca dataset dari file CSV atau sumber data lainnya
df = pd.read_csv('HIV_AIDS.csv')

##Slicing Baris dan Kolom Terpisah
# Slicing untuk memilih baris berdasarkan NIM akhir
nim_akhir = '088'  # Gantilah dengan 3 digit NIM akhir yang sesuai
baris_sliced = df[df['Gender'].str.endswith(nim_akhir):]

# Slicing untuk memilih kolom dari ke-4 hingga kolom terakhir
kolom_sliced = baris_sliced.iloc[0:8, 3:4]

# Tampilkan data yang telah di-slice
print("Metode 1: Data dari baris dengan NIM akhir", nim_akhir, "sampai data terakhir dan kolom dari ke-4 hingga terakhir:")
print(kolom_sliced)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 10
#       7 ##Slicing Baris dan Kolom Terpisah
#       8 # Slicing untuk memilih baris berdasarkan NIM akhir
#       9 nim_akhir = '088'  # Gantilah dengan 3 digit NIM akhir yang sesuai
# ---> 10 baris_sliced = df[df['Gender'].str.endswith(nim_akhir):]
#      12 # Slicing untuk memilih kolom dari ke-4 hingga kolom terakhir
#      13 kolom_sliced = baris_sliced.iloc[0:8, 3:4]
#
# File ~\venv_jupyterlab\fela-088\lib\site-packages\pandas\core\frame.py:3879, in DataFrame.__getitem__(self, key)
#    3877 # Do we have a slicer (on rows)?
#    3878 if isinstance(key, slice):
# -> 3879     return self._getitem_slice(key)
#    3881 # Do we have a (boolean) DataFrame?
#    3882 if isinstance(key, DataFrame):
#
# ...

# %%
# no 4
import pandas as pd

# Baca dataset dari file CSV atau sumber data lainnya
df = pd.read_csv('HIV_AIDS.csv')

##Slicing Baris dan Kolom Bersamaan
# Slicing untuk memilih baris berdasarkan NIM akhir
nim_akhir = '088'  # Gantilah dengan 3 digit NIM akhir yang sesuai
data_sliced = df[df['Borough'].str.endswith(nim_akhir)].iloc[0:8, 3:4 ]


# Tampilkan data yang telah di-slice
print("Metode 2: Data dari baris dengan NIM akhir", nim_akhir, "sampai data terakhir dan kolom dari ke-4 hingga terakhir:")
print(data_sliced)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 10
#       7 ##Slicing Baris dan Kolom Bersamaan
#       8 # Slicing untuk memilih baris berdasarkan NIM akhir
#       9 nim_akhir = '088'  # Gantilah dengan 3 digit NIM akhir yang sesuai
# ---> 10 data_sliced = df[df['Borough'].str.endswith(nim_akhir)].iloc[3 ]
#      13 # Tampilkan data yang telah di-slice
#      14 print("Metode 2: Data dari baris dengan NIM akhir", nim_akhir, "sampai data terakhir dan kolom dari ke-4 hingga terakhir:")
#
# File ~\venv_jupyterlab\fela-088\lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
#soal no 5
# Pilih atribut yang bernilai objek
atribut_objek = df.select_dtypes(include=['object'])

# Hitung jumlah label yang unik pada setiap atribut yang bernilai objek
jumlah_label = atribut_objek.nunique()

# Tampilkan hasil
print("Jumlah label dari semua atribut yang bernilai objek:")
print(jumlah_label)
# Out:
# Jumlah label dari semua atribut yang bernilai objek:
# Borough     6
# UHF        43
# Gender      4
# Age         7
# Race        6
# dtype: int64
